# callcard    0.117361    0.010286   0.053989    0.201131   -0.064774
# wireless   -0.014184    0.022795   0.011488    0.293719    0.036080
# longmon     6.519119    0.687129   0.911854    0.773976   -1.313450
# tollmon     0.941205    1.937243   0.083565   11.043719    0.102161
# equipmon   -0.893211    0.260437   1.412046    7.043926    2.271716
# cardmon     5.053713    1.001033   0.816870    4.951853   -1.191244
# wiremon     0.373743    2.022496   0.491255   14.589623    1.746553
# longten   470.988845   51.071965  74.844521   54.851149 -100.159817
# tollten   208.596783  125.389192  15.476431  437.458229  -22.188618
# cardten   433.678707   70.401912  81.412797  166.553737  -97.918329
# voice      -0.019562    0.028820   0.016830    0.296357    0.029598
# pager       0.005162    0.029140   0.053579    0.315955    0.025377
# internet   -0.073593    0.005315   0.025320    0.086432    0.057688
# callwait    0.010432    0.020654   0.026259    0.370729   -0.012010
# confer      0.024723    0.033025  -0.001866    0.363317   -0.018492
# ebill      -0.048513    0.003466   0.014657    0.056281    0.057688
# loglong     0.534773    0.061088   0.100387    0.095095   -0.112063
# logtoll     0.061088    0.078972  -0.022164    0.070726   -0.008968
# lninc       0.100387   -0.022164   0.566335    0.099500   -0.040210
# custcat     0.095095    0.070726   0.099500    1.165201    0.007286
# churn      -0.112063   -0.008968  -0.040210    0.007286    0.206935
#
# [28 rows x 28 columns]

# %%
A = np.array(churn_df.values)
A.shape
# Out:
# (200, 28)

# %%
columns = churn_df.columns[:-1]
columns.size
# Out:
# 27

# %%
X = np.asarray(churn_df.loc[:, columns], dtype=np.float32)
y = np.asarray(churn_df['churn'])

# %%
# train / test dataset split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (160, 27)
# (40, 27)

# %% [markdown]
# ### PCA 적용 전 Logistic Regression

# %%
# Fitting Logistic Regression
clf = LogisticRegression(solver='lbfgs', random_state=0)
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# predict test set
y_pred = clf.predict(X_test)
# Confusion matrix
accuracy_score(y_test, y_pred)
# Out:
# 0.775

# %% [markdown]
# ### PCA 적용
#
# - 27 개의 feature 를 2 개로 차원 축소

# %%
# Apply kernel PCA
from sklearn.decomposition import PCA

pca = PCA(n_components=2)                # 2 개 component 로 차원 축소

X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
print("차원 축소된 X_train :", X_train_pca.shape)
print(X_train_pca[:5])
print()
print("차원 축소된 X_test :", X_test_pca.shape)
print(X_test_pca[:5])
# Out:
# 차원 축소된 X_train : (160, 2)
# [[ 6.1252427  -2.9101825 ]
#  [-1.7907636   2.6611078 ]
#  [-0.6123653   2.6992145 ]
#  [ 0.11432906 -1.7805345 ]
#  [ 3.1427593   4.7126474 ]]
#
# 차원 축소된 X_test : (40, 2)
# [[ 0.517728    1.3013049 ]
#  [-0.2538366  -2.9665475 ]
#  [-4.058648   -0.6377735 ]
#  [-0.5239167   3.185847  ]
#  [ 0.64675385  1.1866788 ]]

# %%
print(pca.components_.shape)
print("첫번째 주성분 :")
print(pca.components_[0])
print('설명된 분산의 비율', pca.explained_variance_ratio_)
# Out:
# (2, 27)
# 첫번째 주성분 :
# [0.18870449 0.09407663 0.06999469 0.02405294 0.08039848 0.10532499
#  0.09130017 0.22012776 0.24022882 0.1703587  0.2678314  0.16389638
#  0.25017655 0.28326163 0.1763821  0.2743571  0.22993164 0.24062625
#  0.26112375 0.07475983 0.22729254 0.21587749 0.06959318 0.17457926
#  0.17900118 0.07082605 0.29323992]
# 설명된 분산의 비율 [0.25193477 0.2176447 ]

# %%
# Fitting Logistic Regression
clf = LogisticRegression(solver='lbfgs', random_state=0)
clf.fit(X_train_pca, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# predict test set
y_pred = clf.predict(X_test_pca)

# %%
# Confusion matrix
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.725

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.46957947313785553

# %% [markdown]
# ## 차원 축소된 churn data 시각화
# - 27 개의 feature 가 2 개의 PCA 로 차원 축소 되었으므로 평면상의 시각화 가능

# %%
X_train_pca.shape
# Out:
# (160, 2)

# %%
from matplotlib.colors import ListedColormap

cmap = ListedColormap(['r', 'b'])

X1, X2 = X_train_pca[y_train == 0, 0], X_train_pca[y_train == 0, 1]
plt.scatter(X1, X2, color=cmap(0), label=0)

X1, X2 = X_train_pca[y_train == 1, 0], X_train_pca[y_train == 1, 1]
plt.scatter(X1, X2, color=cmap(1), label=1)

plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.legend()
plt.title('Dimension Reduced churn data');
plt.show()

# %%
plt.scatter(X_train_pca[:, 0], y_train, c='b')
plt.scatter(X_train_pca[:, 1], y_train, alpha=0.5, c='r')
plt.xlabel("PCA1(blue), PCA2(red)")
plt.ylabel("churn")
plt.show()

# %% [markdown]
# ### 3 차원 축소

# %%
pca = PCA(n_components=3)                # 2 개 component 로 차원 축소

X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

print("차원 축소된 X_train :", X_train_pca.shape)
print(X_train_pca[:5])
print()
print("차원 축소된 X_test :", X_test_pca.shape)
print(X_test_pca[:5])
print()
print('설명된 분산의 비율', pca.explained_variance_ratio_)
# Out:
# 차원 축소된 X_train : (160, 3)
# [[ 6.1252427  -2.9101825  -0.31197983]
#  [-1.7907636   2.6611078   1.2601514 ]
#  [-0.6123653   2.6992145  -0.22648107]
#  [ 0.11432906 -1.7805345  -2.2009366 ]
#  [ 3.1427593   4.7126474  -0.55305433]]
#
# 차원 축소된 X_test : (40, 3)
# [[ 0.517728    1.3013049   1.5810984 ]
#  [-0.2538366  -2.9665475   0.6917321 ]
#  [-4.058648   -0.6377735  -0.9527021 ]
#  [-0.5239167   3.185847    1.3873055 ]
#  [ 0.64675385  1.1866788  -2.1136382 ]]
#
# 설명된 분산의 비율 [0.25193477 0.2176447  0.11380335]

# %% [markdown]
# ### 3 차원 시각화

# %%
from mpl_toolkits.mplot3d import axes3d, Axes3D 
 
fig = plt.figure(figsize=(12, 8))
ax = Axes3D(fig) 

ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train_pca[:, 0], X_train_pca[:, 1], X_train_pca[:, 2])

# label the axes
ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
ax.set_zlabel("PC3")
ax.set_title("PCA on the churn data set")
plt.show()

# %% [markdown]
# # 실습 - Cell sample data 를 이용한 PCA + SVC

# %%
cell_df = pd.read_csv("datasets/cell_samples.csv")

# %%
feature_df = cell_df.drop(['ID', 'BareNuc'], axis=1)
feature_df.head()
# Out:
#    Clump  UnifSize  UnifShape  MargAdh  SingEpiSize  BlandChrom  NormNucl  \
# 0      5         1          1        1            2           3         1
# 1      5         4          4        5            7           3         2
# 2      3         1          1        1            2           3         1
# 3      6         8          8        1            3           3         7
# 4      4         1          1        3            2           3         1
#
#    Mit  Class
# 0    1      2
# 1    1      2
# 2    1      2
# 3    1      2
# 4    1      2

# %%
# Scaling, Train / Test split

# %% [markdown]
# ### PCA 적용전 SVC 로 accuracy test

# %%
# Your code here

# %% [markdown]
# ### PCA 적용후 SVC 로 accuracy test 하여 전과 비교

# %%
# Your code here
